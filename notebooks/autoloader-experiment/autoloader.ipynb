# %%
from pyspark.sql.types import *
from delta.tables import *
from pyspark.sql.utils import AnalysisException
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
customSchema = StructType([
    StructField("DATE", DateType(), True),        
    StructField("PROVINCE", StringType(), True),
    StructField("REGION", StringType(), True),
    StructField("AGEGROUP", StringType(), True),
    StructField("SEX", StringType(), True),
    StructField("CASES", DoubleType(), True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_keys(keyName:str)->str:
  return dbutils.secrets.get(scope = 'formula1-scope', key = keyName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_format = 'csv'
connection_string = get_keys('storage-account-connectionString')
tenant_id = get_keys('databricks-app-tenant-id')
client_id = get_keys('databricks-app-client-id')
client_secret = get_keys('databricks-app-client-secret')
subscription_id = get_keys('re-subscriber-id')
resoruce_group = 'test-rg'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
subscription_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: &#39;[REDACTED]&#39;</div>

# %%
df = spark.readStream.format("cloudFiles")\
          .option("cloudFiles.format", "csv")\
          .option("cloudFiles.connectionString", connection_string)\
          .option("cloudFiles.resourceGroup", resoruce_group)\
          .option("cloudFiles.subscriptionId", subscription_id)\
          .option("cloudFiles.tenantId", tenant_id)\
          .option("cloudFiles.clientId", client_id)\
          .option("cloudFiles.clientSecret", client_secret)\
          .option("cloudFiles.validateOptions", "false")\
          .option("header","true")\
          .schema(customSchema)\
          .load("/mnt/f234dl/raw/covid_daily")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
CREATE TABLE IF NOT EXISTS covid_data
   (DATE DATE,
   PROVINCE STRING,
   REGION STRING,
   AGEGROUP STRING,
   SEX STRING,
   CASES DOUBLE)
  USING DELTA
  LOCATION '/mnt/f234dl/processed/covid_processed_daily'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
def upsert_data(df, epochId):
    deltaTable = DeltaTable.forPath(spark, "/mnt/f234dl/processed/covid_processed_daily")
    deltaTable.alias("data").merge(
      df.alias("newData"),
      "data.DATE = newData.DATE and data.PROVINCE = newData.PROVINCE and data.AGEGROUP = newData.AGEGROUP and data.SEX = newData.SEX") \
    .whenNotMatchedInsertAll() \
    .execute()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.writeStream\
  .format("delta")\
  .foreachBatch(upsert_data)\
  .option("checkpointLocation", "/mnt/f234dl/processed/checkpoints")\
  .start("/mnt/f234dl/processed/covid_processed_daily")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7fcdb0d63fd0&gt;</div>

# %%
# %sql
SELECT * FROM delta.`/mnt/f234dl/processed/covid_processed_daily`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DATE</th><th>PROVINCE</th><th>REGION</th><th>AGEGROUP</th><th>SEX</th><th>CASES</th></tr></thead><tbody><tr><td>null</td><td>PROVINCE</td><td>REGION</td><td>AGEGROUP</td><td>SEX</td><td>null</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>40-49</td><td>M</td><td>7.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>50-59</td><td>F</td><td>8.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>50-59</td><td>M</td><td>9.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>60-69</td><td>M</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>70-79</td><td>F</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>70-79</td><td>M</td><td>3.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>80-89</td><td>F</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>80-89</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Liège</td><td>Wallonia</td><td>90+</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>20-29</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>20-29</td><td>M</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>30-39</td><td>F</td><td>3.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>40-49</td><td>F</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>40-49</td><td>M</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>50-59</td><td>F</td><td>5.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>50-59</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>60-69</td><td>F</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>60-69</td><td>M</td><td>7.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>70-79</td><td>F</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>70-79</td><td>M</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>80-89</td><td>F</td><td>4.0</td></tr><tr><td>2020-03-22</td><td>Limburg</td><td>Flanders</td><td>80-89</td><td>M</td><td>6.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>20-29</td><td>F</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>50-59</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>50-59</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>60-69</td><td>M</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>70-79</td><td>M</td><td>3.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>80-89</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Luxembourg</td><td>Wallonia</td><td>90+</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>20-29</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>30-39</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>50-59</td><td>F</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>50-59</td><td>M</td><td>3.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>60-69</td><td>M</td><td>1.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>70-79</td><td>F</td><td>2.0</td></tr><tr><td>2020-03-22</td><td>Namur</td><td>Wallonia</td><td>80-89</td><td>F</td><td>3.0</td></tr><tr><td>2 ...

# %%
# %sql
select count(*) from delta.`/mnt/f234dl/processed/covid_processed_daily`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>5003</td></tr></tbody></table></div>
